# %%
def gender_features(word):
    return {'last_letter': word[-1]}
gender_features('Shrek')
# Out:
# {'last_letter': 'k'}

# %%
import nltk
from nltk.corpus import names
labeled_names = ([(name, 'male') for name in names.words('male.txt')] +
[(name, 'female') for name in names.words('female.txt')])
# Create a list of names using two loops and a Concatenation
import random
random.shuffle(labeled_names)
labeled_names[1:20]
# Out:
# [('Hadleigh', 'male'),
#  ('Amelia', 'female'),
#  ('Anjanette', 'female'),
#  ('Wilfred', 'male'),
#  ('Theobald', 'male'),
#  ('Kyle', 'male'),
#  ('Blanch', 'female'),
#  ('Etheline', 'female'),
#  ('Orel', 'female'),
#  ('Karyl', 'female'),
#  ('Montgomery', 'male'),
#  ('Kimmo', 'male'),
#  ('Noreen', 'female'),
#  ('Danika', 'female'),
#  ('Salomo', 'male'),
#  ('Talbert', 'male'),
#  ('Ronen', 'male'),
#  ('Yoko', 'female'),
#  ('Matteo', 'male')]

# %%
featuresets = [(gender_features(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(classifier.classify(gender_features('Neo')) )
classifier.classify(gender_features('Trinty'))
# Out:
# male
# 'female'

# %%
print(nltk.classify.accuracy(classifier, test_set))
classifier.show_most_informative_features(30)
# Out:
# 0.748
# Most Informative Features
#              last_letter = 'a'            female : male   =     39.2 : 1.0
#              last_letter = 'k'              male : female =     36.9 : 1.0
#              last_letter = 'f'              male : female =     24.7 : 1.0
#              last_letter = 'p'              male : female =     20.1 : 1.0
#              last_letter = 'v'              male : female =     11.4 : 1.0
#              last_letter = 'o'              male : female =     10.0 : 1.0
#              last_letter = 'm'              male : female =      8.3 : 1.0
#              last_letter = 'd'              male : female =      8.2 : 1.0
#              last_letter = 'u'              male : female =      7.3 : 1.0
#              last_letter = 'r'              male : female =      6.7 : 1.0
#              last_letter = 'g'              male : female =      5.4 : 1.0
#              last_letter = 'w'              male : female =      4.6 : 1.0
# ...

# %%
for name in labeled_names:
    nameletter = gender_features(name[0])
    if nameletter['last_letter'] == "a":
       print(name[0])
# Out:
# Cleva
# Miguelita
# Franciska
# Cecelia
# Georgina
# Anissa
# Ardella
# Toma
# Irita
# Harrietta
# Auberta
# Theodora
# Basia
# Danya
# Correna
# Angelina
# Arabela
# Aretha
# Anitra
# Janessa
# Eirena
# Katusha
# Clara
# Tamera
# Malinda
# Morganica
# Fanya
# Larissa
# Tressa
# Albertina
# Imelda
# Barbabra
# Hedda
# Tammara
# Linnea
# Silvana
# Sharra
# Zea
# Robena
# Renata
# Feodora
# Meara
# Andria
# Jenna
# Ariella
# Florentia
# Delcina
# Brunhilda
# Verina
# Julieta
# Marcelia
# Geralda
# Eleanora
# Tonia
# Marita
# Lela
# Gina
# Dyanna
# Genna
# Shoshanna
# Latrena
# Kanya
# Malvina
# Pauletta
# Denna
# Roxanna
# Vanya
# Isabella
# Phaedra
# Ulla
# Karena
# Dolora
# Rora
# Lonna
# Paulina
# Babara
# Rosemaria
# Idalia
# Germana
# Suzanna
# Krishna
# Dorothea
# Vita
# Ramonda
# Kelila
# Camellia
# Agatha
# Goldina
# Emelita
# Moyra
# Marina
# Marcela
# Lita
# Xaviera
# Louella
# Thea
# Faina
# Sarita
# Rica
# Prunella
# Agneta
# Latrina
# Alethea
# Janina
# Felita
# Nita
# ...

# %%
 
def gender_features2(name):
    features = {}
    features["first_letter"] = name[0].lower()
    features["last_letter"] = name[-1].lower()
    for letter in 'abcdefghijklmnopqrstuvwxyz':
        features["count({})".format(letter)] = name.lower().count(letter)
        features["has({})".format(letter)] = (letter in name.lower())
    return features

# %%
# gender_features2('Penelope')

# %%
featuresets = [(gender_features2(n), gender) for (n, gender) in labeled_names]
train_set, test_set = featuresets[500:], featuresets[:500]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.758

# %% [markdown]
# ### Divide the set into three groups for Training, Testing, and Development

# %%
train_names = labeled_names[1500:]
devtest_names = labeled_names[500:1500]
test_names = labeled_names[:500]

# %% [markdown]
# ### Generate sets (list) from Data (ABOVE) and Run Classifier. Note train with training set,
# ### Do error analysis with dev-test set (BELOW)

# %%
train_set = [(gender_features(n), gender) for (n, gender) in train_names]
devtest_set = [(gender_features(n), gender) for (n, gender) in devtest_names]
test_set = [(gender_features(n), gender) for (n, gender) in test_names]
classifier = nltk.NaiveBayesClassifier.train(train_set)
print(nltk.classify.accuracy(classifier, devtest_set))
# Out:
# 0.755

# %% [markdown]
# ### Specific errors
# ### Can look for suffixes (a more detailed check), For example female, if end in "n"
# ### are likely to be "yn"

# %%
 
errors = []
for (name, tag) in devtest_names:
     guess = classifier.classify(gender_features(name))
     if guess != tag:
         errors.append( (tag, guess, name) )
for (tag, guess, name) in sorted(errors):
     #if name[-1] == 'n': print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))
     print('correct={:<8} guess={:<8s} name={:<30}'.format(tag, guess, name))
    #print(name[-1])
# Out:
# correct=female   guess=male     name=Aleen
# correct=female   guess=male     name=Anne-Mar
# correct=female   guess=male     name=Ardeen
# correct=female   guess=male     name=Arden
# correct=female   guess=male     name=Ardis
# correct=female   guess=male     name=Austin
# correct=female   guess=male     name=Avrit
# correct=female   guess=male     name=Barb
# correct=female   guess=male     name=Beatriz
# correct=female   guess=male     name=Birgit
# correct=female   guess=male     name=Bliss
# correct=female   guess=male     name=Brenn
# correct=female   guess=male     name=Caren
# correct=female   guess=male     name=Carilyn
# correct=female   guess=male     name=Charleen
# correct=female   guess=male     name=Charlott
# correct=female   guess=male     name=Charmain
# correct=female   guess=male     name=Christan
# correct=female   guess=male     name=Clem
# correct=female   guess=male     name=Corliss
# correct=female   guess=male     name=Dagmar
# ...

# %% [markdown]
# ## CHAPTER 6 OF ONLINE NLTK BOOK (LEARNING TO CLASSIFY TEXT)
# ## EXAMPLE OF DECISION TREE: CLASSIFY MOVIE REVIEWS AS POS
# ## NEG BASED ON SUFFIXES IN WORDS IN REVIEW
